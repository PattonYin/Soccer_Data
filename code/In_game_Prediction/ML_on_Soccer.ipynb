# %%
import pandas as pd

# %%
sample_data = pd.read_csv("../data/3773457.csv", low_memory=False)

# %%
sample_data.head()
# Out:
#    Unnamed: 0                                    id  index  period  \
# 0           0  9d9578b5-c08c-4279-8f74-b6b1497398c1      1       1
# 1           1  5008c221-4ae6-4f3c-b45f-151026e68e6e      2       1
# 2           2  35d940f0-f9ee-47a0-b922-84c0ddaef022      3       1
# 3           3  199204d2-f503-4720-a1a5-dbf9c61095d4      4       1
# 4           4  daac9c8d-95b6-4e42-8cfa-b05779fd7755      5       1
#
#       timestamp  minute  second                               type  \
# 0  00:00:00.000       0       0  {'id': 35, 'name': 'Starting XI'}
# 1  00:00:00.000       0       0  {'id': 35, 'name': 'Starting XI'}
# 2  00:00:00.000       0       0   {'id': 18, 'name': 'Half Start'}
# 3  00:00:00.000       0       0   {'id': 18, 'name': 'Half Start'}
# 4  00:00:00.955       0       0         {'id': 30, 'name': 'Pass'}
#
#    possession                   possession_team  ... off_camera  out  shot  \
# 0           1  {'id': 217, 'name': 'Barcelona'}  ...        NaN  NaN   NaN
# ...
